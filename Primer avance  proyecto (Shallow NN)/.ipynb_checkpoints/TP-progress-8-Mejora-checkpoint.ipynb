# %% [markdown]
# # Avance proyecto - Implementacion Shallow NN
#
# ## Equipo: 8
#
# ## Integrantes:
# * Andres Camilo Torres Cajamarca (antorresca@unal.edu.co)
# * Adrian Ramirez Gonzalez (adramirez@unal.edu.co)
# * Andres Felipe Poveda Bellon (anpovedab@unal.edu.co)
# * Jorge Aurelio Morales Manrique (jomorales@unal.edu.co)
# * Miguel Angel Pinzon Garcia (mipinzong@unal.edu.co)

# %% [markdown]
# # Clasificacion de tumores cerebrales usando una Shallow NN
#
# En este primer avance del proyecto se implementara una red neuronal superficial (Shallow NN) la cual tendra que identificar correctamente la presencia de tumores (o la falta de ellos) en imagenes de resonancias magneticas. La red neuronal tendra que clasificar la imgan en una de las siguientes 4 categorias:
#
# 1. Saludable (No hay tumores)
# 2. Meningioma
# 3. Tumor pituitario
# 4. Glioma

# %% [markdown]
# # Importacion de las librerias
#
# Se realiza la importacion de las librerias que se usaran a lo largo de la construccion y analisis de la red neuronal superficial.

# %%
import keras
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import graycomatrix, graycoprops
import sklearn

# %% [markdown]
# # Preprocesamiento de datos y analisis exploratorio
#
# **Dateset usado:** https://www.kaggle.com/datasets/miadul/brain-tumor-mri-dataset/data
# **Cantidad de imagenes total segun Kaggle:** 7023
#
# Para este caso, el dataset de Kaggle ya viene dividido en 4 carpetas distintas divididas por el tipo de tumor que almacenan. Por esta razon, inicialmente se cargara todo el dataset usando one hot encoding para representar cada categoria.
#
# Las imagenes seran cargadas con una resolucion de 128x128 para mejorar la velocidad de procesamiento. Ademas, estas imagenes seran cargadas en escala de grises, ya que las imagenes de resonancias magneticas presentan colores que se pueden representar en esta escala sin perder informacion util.

# %%
dataset = keras.utils.image_dataset_from_directory(
    "./brain_tumor_dataset",
    labels="inferred",
    color_mode="grayscale",
    label_mode="categorical",
    batch_size=None,
    image_size=(128, 128),
    seed=5125
)
# Out:
# Found 7023 files belonging to 4 classes.

# %% [markdown]
# Se verifica que se hayan detectado correctamente las categorias y que la resolucion de todas las imagenes sea de 128x128 (esto tambien permite verificar que la cantidad de imagenes cargadas coincida con las que reporta Kaggle)

# %%
print(f"Categorias de las imagenes: {dataset.class_names}")

resolutions = dict()

for image, label in dataset:
    if not image.shape in resolutions:
        resolutions[image.shape] = 1
    else:
        resolutions[image.shape] += 1

print("Resoluciones encontradas:")
for key, value in resolutions.items():
    print(f"\t{key[0]}x{key[1]}. Cantidad: {value}")
# Out:
# Categorias de las imagenes: ['glioma', 'healthy', 'meningioma', 'pituitary']
# Resoluciones encontradas:
# 	128x128. Cantidad: 7023

# %% [markdown]
# Se visualizan algunas imagenes al azar para verificar que se vean correctamente

# %%
fig, ax = plt.subplots(3, 2, figsize=(10, 15))

row = 0
col = 0
for image, label in dataset.shuffle(buffer_size=dataset.cardinality()).take(6):
    ax[row][col].imshow(image.numpy().squeeze(), cmap="gray")
    ax[row][col].set_title(dataset.class_names[np.argmax(label.numpy())])
    ax[row][col].axis("off")

    col = col + 1

    if col == 2:
        col = 0
        row = row + 1

# %% [markdown]
# Se cuenta la cantidad de imagenes de cada categoria para verificar que todas las categorias tengan una cantidad similar de imagenes. En este caso, se puede observar que todas las categorias tienen porcentajes similares de imagenes respecto al total del dataset.

# %%
num_glioma = 0
num_healthy = 0
num_meningioma = 0
num_pituitary = 0

for image, label in dataset:
    match np.argmax(label.numpy()):
        case 0:
            num_glioma += 1
        case 1:
            num_healthy += 1
        case 2:
            num_meningioma += 1
        case 3:
            num_pituitary += 1

total = num_glioma + num_healthy + num_meningioma + num_pituitary

print(f"Numero de imagenes de gliomas: {num_glioma}. Porcentaje del total: {np.round((num_glioma/total)*100,2)}%")
print(f"Numero de imagenes saludables: {num_healthy}. Porcentaje del total: {np.round((num_healthy/total)*100,2)}%")
print(f"Numero de imagenes de meningiomas: {num_meningioma}. Porcentaje del total: {np.round((num_meningioma/total)*100,2)}%")
print(f"Numero de imagenes de tumores pituitarios: {num_pituitary}. Porcentaje del total: {np.round((num_pituitary/total)*100,2)}%")
# Out:
# Numero de imagenes de gliomas: 1621. Porcentaje del total: 23.08%
# Numero de imagenes saludables: 2000. Porcentaje del total: 28.48%
# Numero de imagenes de meningiomas: 1645. Porcentaje del total: 23.42%
# Numero de imagenes de tumores pituitarios: 1757. Porcentaje del total: 25.02%

# %% [markdown]
# Se grafica una distribucion por clases para ver mejor la cantidad de imagenes por categoria

# %%
fig, ax = plt.subplots()
ax.bar(["Glioma", "Saludable", "Meningioma", "Pituitario"], [num_glioma, num_healthy, num_meningioma, num_pituitary])

ax.set_title("Distribucion de imagenes por clase")
ax.set_xlabel("Clases")
ax.set_ylabel("Numero de imagenes")
plt.show()

# %% [markdown]
# # Extraccion de caracteristicas y division del dataset
#
# Para el proceso de extraccion de caracteristicas (feature extraction), se usara GLCM (Gray Level Co-occurrence Matrices) a partir de la cual se extraeran los siguientes valores:
#
# 1. Contraste
# 2. Disimilaridad
# 3. Homogeneidad
# 4. ASM
# 5. Energia
# 6. Correlacion
#
# Estos valores se calcularan usando angulo los angulos 0°, 45°, 90° y 135°. Ademas, tambien se define una distancia de 1. En total, se tendra un conjunto de 24 valores que servira como entrada en la red neuronal para cada imagen.
#
# Adicionalmente, en esta seccion tambien se hara la division del dataset en 3 partes: Entrenamiento, validacion y test. Para esta division se utilizaran los siguientes porcentajes:
# 1. **Entrenamiento:** 80%
# 2. **Validacion:** 10%
# 3. **Test:** 10%

# %%
def extract_GLCM(image):
    image = np.squeeze(image.numpy()).astype(np.uint8)

    features = []
    glcm = graycomatrix(image, distances=[1], angles=[0, np.pi/4, np.pi/2, 3*np.pi/4], levels=256, symmetric=True, normed=True)

    features.extend(graycoprops(glcm, 'contrast').flatten())
    features.extend(graycoprops(glcm, 'dissimilarity').flatten())
    features.extend(graycoprops(glcm, 'homogeneity').flatten())
    features.extend(graycoprops(glcm, 'ASM').flatten())
    features.extend(graycoprops(glcm, 'energy').flatten())
    features.extend(graycoprops(glcm, 'correlation').flatten())

    return features

train_rate = 0.8
validation_rate = 0.1
test_rate = 0.1
total = int(dataset.cardinality())

train_quantity = int(total * train_rate)
validation_quantity = int(total * validation_rate)
test_quantity = int(total * test_rate)

train_data = []
train_results = []

validation_data = []
validation_results = []

test_data = []
test_results = []

counter = 0
for image, label in dataset.shuffle(buffer_size=dataset.cardinality()):
    feature_extraction = extract_GLCM(image)

    if counter < train_quantity:
        train_data.append(feature_extraction)
        train_results.append(label.numpy())

    elif train_quantity <= counter < train_quantity + validation_quantity:
        validation_data.append(feature_extraction)
        validation_results.append(label.numpy())

    elif train_quantity + validation_quantity <= counter < total:
        test_data.append(feature_extraction)
        test_results.append(label.numpy())

    counter += 1

train_data = np.array(train_data)
train_results = np.array(train_results)

validation_data = np.array(validation_data)
validation_results = np.array(validation_results)

test_data = np.array(test_data)
test_results = np.array(test_results)

# %% [markdown]
# Se verifica que los datos hayan quedado correctamente divididos

# %%
print(f"Cantidad de datos de entrenamiento: {len(train_data)}. Porcentaje: {np.round((len(train_data)/total)*100,2)}%")
print(f"Cantidad de datos de validacion: {len(validation_data)}. Porcentaje: {np.round((len(validation_data)/total)*100,2)}%")
print(f"Cantidad de datos de test: {len(test_data)}. Porcentaje: {np.round((len(test_data)/total)*100,2)}%")
# Out:
# Cantidad de datos de entrenamiento: 5618. Porcentaje: 79.99%
# Cantidad de datos de validacion: 702. Porcentaje: 10.0%
# Cantidad de datos de test: 703. Porcentaje: 10.01%

# %% [markdown]
# # Construccion de la Red neuronal superficial (shallow NN)
#
# La red neuronal se compondra de una capa de entrada, una capa oculta y una capa de salida. Estas capas tendran las siguientes caracteristicas:
#
# ## Capas
# #### Capa de entrada
# * Tamaño: 24 valores
#
# #### Capa oculta
# * Tamaño: 50 neuronas
# * Funcion de activacion: ReLU
#
# #### Capa de salida
# * Tamaño: 4 neuronas
# * Funcion de activacion: Softmax
#
# La red neuronal sera entrenda durante 100 epochs usando la entropia categorica cruzada como funcion de perdida y Adam como optimizador.

# %%
model = keras.Sequential(
    [
        keras.Input((train_data.shape[1],)),
        layers.Dense(100, activation="relu", name="hidden_layer_1"),
        layers.Dense(4, activation="softmax", name="output_layer"),
    ])

model.summary()

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
)

epochs = 100

train_model = model.fit(
    train_data,
    train_results,
    epochs=epochs,
    validation_data=(validation_data,validation_results)
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden_layer_1 (Dense)          │ (None, 100)            │         2,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 4)              │           404 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,904 (11.34 KB)
#  Trainable params: 2,904 (11.34 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3136 - loss: 5.6953 - val_accuracy: 0.4915 - val_loss: 2.8988
# Epoch 2/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.4402 - loss: 1.6998 - val_accuracy: 0.4972 - val_loss: 1.3003
# Epoch 3/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.4941 - loss: 1.6910 - val_accuracy: 0.5698 - val_loss: 1.2382
# Epoch 4/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.5449 - loss: 1.2707 - val_accuracy: 0.6068 - val_loss: 1.0110
# Epoch 5/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - accuracy: 0.5329 - loss: 1.4388 - val_accuracy: 0.5256 - val_loss: 1.3545
# Epoch 6/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.5441 - loss: 1.3550 - val_accuracy: 0.5670 - val_loss: 1.2234
# Epoch 7/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 0.5566 - loss: 1.3573 - val_accuracy: 0.6339 - val_loss: 1.3672
# Epoch 8/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.5224 - loss: 1.6276 - val_accuracy: 0.6538 - val_loss: 1.0143
# Epoch 9/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.5755 - loss: 1.3253 - val_accuracy: 0.6054 - val_loss: 1.2058
# Epoch 10/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.5637 - loss: 1.3481 - val_accuracy: 0.5769 - val_loss: 2.6258
# Epoch 11/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 0.5434 - loss: 1.6813 - val_accuracy: 0.4444 - val_loss: 2.0538
# Epoch 12/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.5983 - loss: 1.2120 - val_accuracy: 0.5100 - val_loss: 1.6012
# Epoch 13/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.5801 - loss: 1.3016 - val_accuracy: 0.5328 - val_loss: 2.6449
# Epoch 14/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.5546 - loss: 1.4979 - val_accuracy: 0.5028 - val_loss: 1.5755
# Epoch 15/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.5696 - loss: 1.3718 - val_accuracy: 0.6026 - val_loss: 1.3055
# Epoch 16/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5771 - loss: 1.2911 - val_accuracy: 0.4373 - val_loss: 1.6270
# Epoch 17/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5717 - loss: 1.4077 - val_accuracy: 0.5100 - val_loss: 1.3060
# Epoch 18/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5771 - loss: 1.4155 - val_accuracy: 0.5912 - val_loss: 1.0570
# Epoch 19/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5902 - loss: 1.3032 - val_accuracy: 0.6524 - val_loss: 1.0085
# Epoch 20/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.5684 - loss: 1.4609 - val_accuracy: 0.5613 - val_loss: 1.5525
# Epoch 21/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5774 - loss: 1.4026 - val_accuracy: 0.6638 - val_loss: 0.9628
# Epoch 22/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.5888 - loss: 1.3187 - val_accuracy: 0.6054 - val_loss: 1.1067
# Epoch 23/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.5733 - loss: 1.4109 - val_accuracy: 0.5427 - val_loss: 2.7974
# Epoch 24/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.5819 - loss: 1.4234 - val_accuracy: 0.5869 - val_loss: 1.3394
# Epoch 25/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.5997 - loss: 1.2785 - val_accuracy: 0.6667 - val_loss: 1.0024
# Epoch 26/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.5746 - loss: 1.4065 - val_accuracy: 0.6211 - val_loss: 1.3452
# Epoch 27/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.5687 - loss: 1.4165 - val_accuracy: 0.5983 - val_loss: 1.1518
# Epoch 28/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.6095 - loss: 1.2001 - val_accuracy: 0.6781 - val_loss: 0.8854
# Epoch 29/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.6068 - loss: 1.1809 - val_accuracy: 0.5299 - val_loss: 1.2196
# Epoch 30/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.6050 - loss: 1.1748 - val_accuracy: 0.6083 - val_loss: 1.1634
# Epoch 31/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.6077 - loss: 1.2093 - val_accuracy: 0.6439 - val_loss: 1.0095
# Epoch 32/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5993 - loss: 1.2734 - val_accuracy: 0.6168 - val_loss: 1.2431
# Epoch 33/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.6022 - loss: 1.2205 - val_accuracy: 0.4544 - val_loss: 2.2236
# Epoch 34/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.5895 - loss: 1.3551 - val_accuracy: 0.5114 - val_loss: 1.3162
# Epoch 35/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.5940 - loss: 1.2937 - val_accuracy: 0.3604 - val_loss: 2.5419
# Epoch 36/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.5571 - loss: 1.6249 - val_accuracy: 0.4815 - val_loss: 1.9517
# Epoch 37/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.6317 - loss: 1.0985 - val_accuracy: 0.6197 - val_loss: 1.0021
# Epoch 38/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6063 - loss: 1.2007 - val_accuracy: 0.6225 - val_loss: 1.2019
# Epoch 39/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - accuracy: 0.6041 - loss: 1.2264 - val_accuracy: 0.6353 - val_loss: 1.0702
# Epoch 40/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.6002 - loss: 1.2310 - val_accuracy: 0.6254 - val_loss: 1.0863
# Epoch 41/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.6041 - loss: 1.1928 - val_accuracy: 0.6652 - val_loss: 0.9088
# Epoch 42/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - accuracy: 0.6191 - loss: 1.1754 - val_accuracy: 0.5456 - val_loss: 2.0728
# Epoch 43/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.5872 - loss: 1.4049 - val_accuracy: 0.6481 - val_loss: 0.9319
# Epoch 44/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 0.6145 - loss: 1.1312 - val_accuracy: 0.5570 - val_loss: 1.6235
# Epoch 45/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.5940 - loss: 1.4071 - val_accuracy: 0.6496 - val_loss: 1.0298
# Epoch 46/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.6023 - loss: 1.2435 - val_accuracy: 0.6125 - val_loss: 1.1757
# Epoch 47/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - accuracy: 0.6096 - loss: 1.1995 - val_accuracy: 0.5840 - val_loss: 1.2704
# Epoch 48/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.6287 - loss: 1.0657 - val_accuracy: 0.6382 - val_loss: 1.0502
# Epoch 49/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.6251 - loss: 1.1024 - val_accuracy: 0.6624 - val_loss: 0.8746
# Epoch 50/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.6040 - loss: 1.2255 - val_accuracy: 0.6154 - val_loss: 1.2370
# Epoch 51/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.5933 - loss: 1.4009 - val_accuracy: 0.5641 - val_loss: 1.3191
# Epoch 52/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6216 - loss: 1.1378 - val_accuracy: 0.5912 - val_loss: 1.1076
# Epoch 53/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.6187 - loss: 1.1437 - val_accuracy: 0.5670 - val_loss: 1.1184
# Epoch 54/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.5808 - loss: 1.4117 - val_accuracy: 0.6225 - val_loss: 1.2440
# Epoch 55/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.5984 - loss: 1.2789 - val_accuracy: 0.6140 - val_loss: 0.9932
# Epoch 56/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.6207 - loss: 1.1424 - val_accuracy: 0.5570 - val_loss: 1.2348
# Epoch 57/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6232 - loss: 1.1086 - val_accuracy: 0.5997 - val_loss: 1.1522
# Epoch 58/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.6178 - loss: 1.0979 - val_accuracy: 0.6111 - val_loss: 1.2239
# Epoch 59/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - accuracy: 0.6095 - loss: 1.1494 - val_accuracy: 0.5954 - val_loss: 1.1810
# Epoch 60/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.6070 - loss: 1.2272 - val_accuracy: 0.5242 - val_loss: 1.5239
# Epoch 61/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6200 - loss: 1.1507 - val_accuracy: 0.6766 - val_loss: 0.9007
# Epoch 62/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.6248 - loss: 1.0700 - val_accuracy: 0.6425 - val_loss: 0.9619
# Epoch 63/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.6171 - loss: 1.1681 - val_accuracy: 0.6140 - val_loss: 1.0585
# Epoch 64/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.6285 - loss: 1.0701 - val_accuracy: 0.6068 - val_loss: 1.0641
# Epoch 65/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6294 - loss: 1.0588 - val_accuracy: 0.6752 - val_loss: 0.8425
# Epoch 66/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 0.6214 - loss: 1.1005 - val_accuracy: 0.6425 - val_loss: 0.9949
# Epoch 67/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.6358 - loss: 1.0187 - val_accuracy: 0.5912 - val_loss: 1.1547
# Epoch 68/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.5949 - loss: 1.2258 - val_accuracy: 0.4601 - val_loss: 1.5016
# Epoch 69/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6025 - loss: 1.2716 - val_accuracy: 0.5598 - val_loss: 1.1148
# Epoch 70/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.6369 - loss: 1.0773 - val_accuracy: 0.6425 - val_loss: 1.0347
# Epoch 71/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6347 - loss: 1.0287 - val_accuracy: 0.6353 - val_loss: 1.1285
# Epoch 72/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.5988 - loss: 1.2550 - val_accuracy: 0.6382 - val_loss: 1.0766
# Epoch 73/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.6191 - loss: 1.0841 - val_accuracy: 0.6026 - val_loss: 1.3834
# Epoch 74/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.6290 - loss: 1.0553 - val_accuracy: 0.5541 - val_loss: 1.1759
# Epoch 75/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 0.6406 - loss: 0.9606 - val_accuracy: 0.6724 - val_loss: 0.9321
# Epoch 76/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.6143 - loss: 1.1836 - val_accuracy: 0.6994 - val_loss: 0.8903
# Epoch 77/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.5913 - loss: 1.2917 - val_accuracy: 0.6011 - val_loss: 1.0386
# Epoch 78/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6394 - loss: 1.0172 - val_accuracy: 0.5812 - val_loss: 1.2844
# Epoch 79/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.6276 - loss: 1.0771 - val_accuracy: 0.5271 - val_loss: 1.3629
# Epoch 80/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.6312 - loss: 1.0790 - val_accuracy: 0.7023 - val_loss: 0.8373
# Epoch 81/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6218 - loss: 1.0552 - val_accuracy: 0.6638 - val_loss: 0.8809
# Epoch 82/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.6556 - loss: 0.9640 - val_accuracy: 0.6752 - val_loss: 0.8533
# Epoch 83/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 0.6155 - loss: 1.0955 - val_accuracy: 0.6638 - val_loss: 1.0608
# Epoch 84/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 0.6328 - loss: 1.0568 - val_accuracy: 0.6966 - val_loss: 0.8893
# Epoch 85/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - accuracy: 0.6239 - loss: 1.0929 - val_accuracy: 0.6895 - val_loss: 0.8157
# Epoch 86/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.6258 - loss: 1.0794 - val_accuracy: 0.6154 - val_loss: 1.1719
# Epoch 87/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6216 - loss: 1.0842 - val_accuracy: 0.6140 - val_loss: 1.8196
# Epoch 88/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.6205 - loss: 1.1392 - val_accuracy: 0.6681 - val_loss: 0.8794
# Epoch 89/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.6372 - loss: 1.0190 - val_accuracy: 0.5883 - val_loss: 1.1954
# Epoch 90/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6196 - loss: 1.1061 - val_accuracy: 0.4202 - val_loss: 1.9010
# Epoch 91/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - accuracy: 0.6429 - loss: 1.0149 - val_accuracy: 0.5983 - val_loss: 1.6978
# Epoch 92/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.6109 - loss: 1.1512 - val_accuracy: 0.5228 - val_loss: 1.6893
# Epoch 93/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6282 - loss: 1.1293 - val_accuracy: 0.6681 - val_loss: 0.8869
# Epoch 94/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.6481 - loss: 0.9881 - val_accuracy: 0.5883 - val_loss: 1.1431
# Epoch 95/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.6410 - loss: 0.9666 - val_accuracy: 0.6709 - val_loss: 0.9311
# Epoch 96/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6330 - loss: 1.0501 - val_accuracy: 0.6496 - val_loss: 0.9462
# Epoch 97/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - accuracy: 0.6540 - loss: 0.9452 - val_accuracy: 0.5726 - val_loss: 1.1178
# Epoch 98/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 0.6388 - loss: 1.0072 - val_accuracy: 0.6595 - val_loss: 0.9348
# Epoch 99/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6360 - loss: 1.0526 - val_accuracy: 0.5741 - val_loss: 1.1546
# Epoch 100/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.6376 - loss: 1.0304 - val_accuracy: 0.6510 - val_loss: 0.9091

# %% [markdown]
# # Visualizacion de resultados
#
# Se grafica la funcion de perdida a traves de los epochs tanto para los datos de validacion como para los datos de entrenamiento

# %%
train_loss = train_model.history["loss"]
validation_loss = train_model.history["val_loss"]
train_accuracy = train_model.history["accuracy"]
validation_accuracy = train_model.history["val_accuracy"]

fg, ax = plt.subplots(1,2, figsize=(15, 5))

ax[0].plot(train_loss, label="Train loss")
ax[0].plot(validation_loss, label="Validation loss")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss (Categorical entropy)")
ax[0].set_title("Epoch vs loss (incluyendo todos los epoch)")
ax[0].legend()

ax[1].plot(train_loss[1:], label="Train loss")
ax[1].plot(validation_loss[1:], label="Validation loss")
ax[1].set_title("Epoch vs loss (omitiendo los primeros epoch para ver mejor la curva)")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Loss (Categorical entropy)")
ax[1].legend()

plt.show()

# %% [markdown]
# Se grafica el accuracy a traves de los epochs

# %%
train_accuracy = train_model.history["accuracy"]
validation_accuracy = train_model.history["val_accuracy"]

fg2, ax2 = plt.subplots(figsize=(15, 5))

ax2.plot(train_accuracy, label="Train accuracy")
ax2.plot(validation_accuracy, label="Validation accuracy")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Accuracy")
ax2.set_title("Epoch vs accuracy")
ax2.legend()


plt.show()

# %% [markdown]
# # Calculo de otras metricas
#
# Para verificar el desempeno de la red neuronal se calculan las siguientes metricas por clase:
#
# 1. Accuracy general
# 2. Precision
# 3. Sensitivity (Recall)
# 4. F1 Score
# 5. AUC ROC

# %%
prediction_probability = model.predict(test_data)
prediction = prediction_probability.argmax(axis=1)

result = test_results.argmax(axis=1)

print("Calculo de metricas para el conjunto de test\n")
# Accuracy
acc = sklearn.metrics.accuracy_score(result, prediction)
print(f"ACCURACY")
print(f"Accuracy: {np.round(acc,3)}\n")

# Precision
pre = sklearn.metrics.precision_score(result, prediction, average=None, zero_division=np.nan)
print(f"PRECISION")
print(f"Precision para la clase {dataset.class_names[0]}: {np.round(pre[0],3)}")
print(f"Precision para la clase {dataset.class_names[1]}: {np.round(pre[1],3)}")
print(f"Precision para la clase {dataset.class_names[2]}: {np.round(pre[2],3)}")
print(f"Precision para la clase {dataset.class_names[3]}: {np.round(pre[3],3)}\n")

# Recall (Sensitivity)
sen = sklearn.metrics.recall_score(result, prediction, average=None, zero_division=np.nan)
print(f"SENSITIVITY (RECALL)")
print(f"Sensitivity para la clase {dataset.class_names[0]}: {np.round(sen[0],3)}")
print(f"Sensitivity para la clase {dataset.class_names[1]}: {np.round(sen[1],3)}")
print(f"Sensitivity para la clase {dataset.class_names[2]}: {np.round(sen[2],3)}")
print(f"Sensitivity para la clase {dataset.class_names[3]}: {np.round(sen[3],3)}\n")

# F1-Score
f1_score = sklearn.metrics.f1_score(result, prediction, average=None, zero_division=np.nan)
print(f"F1 SCORE")
print(f"F1 Score para la clase {dataset.class_names[0]}: {np.round(f1_score[0],3)}")
print(f"F1 Score para la clase {dataset.class_names[1]}: {np.round(f1_score[1],3)}")
print(f"F1 Score para la clase {dataset.class_names[2]}: {np.round(f1_score[2],3)}")
print(f"F1 Score para la clase {dataset.class_names[3]}: {np.round(f1_score[3],3)}\n")

# AUC ROC
auc_roc = sklearn.metrics.roc_auc_score(result, prediction_probability, average=None, multi_class="ovr")
print(f"AUC ROC")
print(f"AUC ROC para la clase {dataset.class_names[0]}: {np.round(auc_roc[0],3)}")
print(f"AUC ROC para la clase {dataset.class_names[1]}: {np.round(auc_roc[1],3)}")
print(f"AUC ROC para la clase {dataset.class_names[2]}: {np.round(auc_roc[2],3)}")
print(f"AUC ROC para la clase {dataset.class_names[3]}: {np.round(auc_roc[3],3)}\n")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Calculo de metricas para el conjunto de test
#
# ACCURACY
# Accuracy: 0.643
#
# PRECISION
# Precision para la clase glioma: 0.636
# Precision para la clase healthy: 0.88
# Precision para la clase meningioma: 0.435
# Precision para la clase pituitary: 0.79
#
# SENSITIVITY (RECALL)
# Sensitivity para la clase glioma: 0.526
# Sensitivity para la clase healthy: 0.761
# Sensitivity para la clase meningioma: 0.741
# Sensitivity para la clase pituitary: 0.51
#
# F1 SCORE
# F1 Score para la clase glioma: 0.576
# F1 Score para la clase healthy: 0.816
# F1 Score para la clase meningioma: 0.548
# F1 Score para la clase pituitary: 0.62
#
# AUC ROC
# AUC ROC para la clase glioma: 0.873
# AUC ROC para la clase healthy: 0.917
# AUC ROC para la clase meningioma: 0.81
# AUC ROC para la clase pituitary: 0.903

# %% [markdown]
# Por ultimo, se grafica la matriz de confusion

# %%
confusion_mat = sklearn.metrics.confusion_matrix(result, prediction)

visualization = sklearn.metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_mat, display_labels=dataset.class_names)

visualization.plot(cmap="Greens")
plt.show()
